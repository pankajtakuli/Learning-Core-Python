# %% [markdown]
# <font size = "5">***What is a Python Library***

# %% [markdown]
# A Python Library is a collection of ready made code -- functions, classes, and modules -- That you can resuse in your programes instead of writing everything for search.

# %%
import math

print("Square root of 2 is :",math.sqrt(2))
print(math.atan(45))
# Out:
# Square root of 2 is : 1.4142135623730951
# 1.5485777614681775

# %%
from datetime import date

t = date.today()
print(t)
# Out:
# 2025-10-28
