# %%
import pandas as pd

# %% [markdown]
# ### Reading a .csv(comma seperated value) files as a pandas DataFrame

# %%
df = pd.read_csv("titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #### Printing the first few rows of the DataFrame.

# %%
df.head() # Prints the first 5 rows of the DataFrame
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(20) # Prints first 20 rows of the Dataframe
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %% [markdown]
# #### Printing the last few rows of the DataFrame.

# %%
df.tail() # Prints the last 5 rows of the DataFrame
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(20) # Prints the last 20 rows of the DataFrame
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# 874          875         1       2
# 875          876         1       3
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# ...

# %%
df.head(60) # We can printed max 60 rows
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df.head(0) # Range 0 prints heading only of the following table
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %% [markdown]
# ### Checking the Shape of the DataFrame

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### Printing some statistics of your DataFrame

# %%
df.describe() # This gives the summary statistics of your DataFrame

# count numbers of non-missing values
# mean
# std: standard deviation
# min: minimum value of the column
# 25%: 25th percentile of the column
# 50%: 50th percentile of the column
# 75&: 75th percentile of the column
# max: maximum value of the column
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info() # Shows the datatypes, number of non-missing values of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Selecting and Viewing your data

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
# Selecting Multiple Column
df[['Name','Age','Survived']]
# Out:
#                                                   Name   Age  Survived
# 0                              Braund, Mr. Owen Harris  22.0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                               Heikkinen, Miss. Laina  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                             Allen, Mr. William Henry  35.0         0
# ..                                                 ...   ...       ...
# 886                              Montvila, Rev. Juozas  27.0         0
# 887                       Graham, Miss. Margaret Edith  19.0         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN         0
# 889                              Behr, Mr. Karl Howell  26.0         1
# 890                                Dooley, Mr. Patrick  32.0         0
#
# [891 rows x 3 columns]

# %%
df['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df[['PassengerId','Name','Ticket']]
# Out:
#      PassengerId                                               Name  \
# 0              1                            Braund, Mr. Owen Harris
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3                             Heikkinen, Miss. Laina
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5                           Allen, Mr. William Henry
# ..           ...                                                ...
# 886          887                              Montvila, Rev. Juozas
# 887          888                       Graham, Miss. Margaret Edith
# 888          889           Johnston, Miss. Catherine Helen "Carrie"
# 889          890                              Behr, Mr. Karl Howell
# 890          891                                Dooley, Mr. Patrick
#
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ...

# %%
df['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
df[['Cabin','Age']]
# Out:
#     Cabin   Age
# 0     NaN  22.0
# 1     C85  38.0
# 2     NaN  26.0
# 3    C123  35.0
# 4     NaN  35.0
# ..    ...   ...
# 886   NaN  27.0
# 887   B42  19.0
# 888   NaN   NaN
# 889  C148  26.0
# 890   NaN  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# ### Checking missing values in the dataframe

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ### Renaming columns in your Dataframe

# %%
df.rename(columns = {'PassengerId':'S.no'}) # Renaem column for only this time
# Out:
#      S.no  Survived  Pclass  \
# 0       1         0       3
# 1       2         1       1
# 2       3         1       3
# 3       4         1       1
# 4       5         0       3
# ..    ...       ...     ...
# 886   887         0       2
# 887   888         1       1
# 888   889         0       3
# 889   890         1       1
# 890   891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.rename(columns = {'PassengerId':'S.no'},inplace = True) # Rename Columns for permanent

# %%
df
# Out:
#      S.no  Survived  Pclass  \
# 0       1         0       3
# 1       2         1       1
# 2       3         1       3
# 3       4         1       1
# 4       5         0       3
# ..    ...       ...     ...
# 886   887         0       2
# 887   888         1       1
# 888   889         0       3
# 889   890         1       1
# 890   891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ...

# %%
df.rename(columns = {'S.no':'Pankaj'})
# Out:
#      Pankaj  Survived  Pclass  \
# 0         1         0       3
# 1         2         1       1
# 2         3         1       3
# 3         4         1       1
# 4         5         0       3
# ..      ...       ...     ...
# 886     887         0       2
# 887     888         1       1
# 888     889         0       3
# 889     890         1       1
# 890     891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      S.no  Survived  Pclass  \
# 0       1         0       3
# 1       2         1       1
# 2       3         1       3
# 3       4         1       1
# 4       5         0       3
# ..    ...       ...     ...
# 886   887         0       2
# 887   888         1       1
# 888   889         0       3
# 889   890         1       1
# 890   891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ...

# %% [markdown]
# ### Filtering and Sorting

# %%
df[df['Age']>40]
# Out:
#      S.no  Survived  Pclass  \
# 6       7         0       1
# 11     12         1       1
# 15     16         1       2
# 33     34         0       2
# 35     36         0       1
# ..    ...       ...     ...
# 862   863         1       1
# 865   866         1       2
# 871   872         1       1
# 873   874         0       3
# 879   880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 33                               Wheadon, Mr. Edward H    male  66.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# ...

# %%
df[(df['Age']>50) & (df['Sex']=='male')]
# Out:
#      S.no  Survived  Pclass                                  Name   Sex   Age  \
# 6       7         0       1               McCarthy, Mr. Timothy J  male  54.0
# 33     34         0       2                 Wheadon, Mr. Edward H  male  66.0
# 54     55         0       1        Ostby, Mr. Engelhart Cornelius  male  65.0
# 94     95         0       3                     Coxon, Mr. Daniel  male  59.0
# 96     97         0       1             Goldschmidt, Mr. George B  male  71.0
# 116   117         0       3                  Connors, Mr. Patrick  male  70.5
# 124   125         0       1           White, Mr. Percival Wayland  male  54.0
# 150   151         0       2            Bateman, Rev. Robert James  male  51.0
# 152   153         0       3                      Meo, Mr. Alfonzo  male  55.5
# 155   156         0       1           Williams, Mr. Charles Duane  male  51.0
# 170   171         0       1             Van der hoef, Mr. Wyckoff  male  61.0
# ...

# %%
df[(df['Age']>50) & (df['Sex']=='male')][["Name","Age","Sex","Survived"]]
# Out:
#                                      Name   Age   Sex  Survived
# 6                 McCarthy, Mr. Timothy J  54.0  male         0
# 33                  Wheadon, Mr. Edward H  66.0  male         0
# 54         Ostby, Mr. Engelhart Cornelius  65.0  male         0
# 94                      Coxon, Mr. Daniel  59.0  male         0
# 96              Goldschmidt, Mr. George B  71.0  male         0
# 116                  Connors, Mr. Patrick  70.5  male         0
# 124           White, Mr. Percival Wayland  54.0  male         0
# 150            Bateman, Rev. Robert James  51.0  male         0
# 152                      Meo, Mr. Alfonzo  55.5  male         0
# 155           Williams, Mr. Charles Duane  51.0  male         0
# 170             Van der hoef, Mr. Wyckoff  61.0  male         0
# 174               Smith, Mr. James Clinch  56.0  male         0
# 222               Green, Mr. George Henry  51.0  male         0
# 232             Sjostedt, Mr. Ernst Adolf  59.0  male         0
# ...

# %%
df.sort_values('Age',ascending = True)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 803          804         1       3           Thomas, Master. Assad Alexander
# 755          756         1       2                 Hamalainen, Master. Viljo
# 644          645         1       3                    Baclini, Miss. Eugenie
# 469          470         1       3             Baclini, Miss. Helene Barbara
# 78            79         1       2             Caldwell, Master. Alden Gates
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values('Age',ascending = False) # Sorts all the rows based on Age in descending order
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                       Svensson, Mr. Johan
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 96            97         0       1                 Goldschmidt, Mr. George B
# 116          117         0       3                      Connors, Mr. Patrick
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df.sort_values('Age').tail(20).head(10)
# Out:
#      S.no  Survived  Pclass                          Name     Sex  Age  SibSp  \
# 776   777         0       3              Tobin, Mr. Roger    male  NaN      0
# 778   779         0       3       Kilgannon, Mr. Thomas J    male  NaN      0
# 783   784         0       3        Johnston, Mr. Andrew G    male  NaN      1
# 790   791         0       3      Keane, Mr. Andrew "Andy"    male  NaN      0
# 792   793         0       3       Sage, Miss. Stella Anna  female  NaN      8
# 793   794         0       1      Hoyt, Mr. William Fisher    male  NaN      0
# 815   816         0       1              Fry, Mr. Richard    male  NaN      0
# 825   826         0       3               Flynn, Mr. John    male  NaN      0
# 826   827         0       3                  Lam, Mr. Len    male  NaN      0
# 828   829         1       3  McCormack, Mr. Thomas Joseph    male  NaN      0
#
#      Parch      Ticket     Fare Cabin Embarked
# 776      0      383121   7.7500   F38        Q
# ...

# %% [markdown]
# ### Droping Columns in your DataFrame

# %%
df.drop(columns = {'Embarked','Cabin'})
# Out:
#      S.no  Survived  Pclass  \
# 0       1         0       3
# 1       2         1       1
# 2       3         1       3
# 3       4         1       1
# 4       5         0       3
# ..    ...       ...     ...
# 886   887         0       2
# 887   888         1       1
# 888   889         0       3
# 889   890         1       1
# 890   891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ...

# %%
# Use inplace = True for changes in the DataFrame

# %%
df
# Out:
#      S.no  Survived  Pclass  \
# 0       1         0       3
# 1       2         1       1
# 2       3         1       3
# 3       4         1       1
# 4       5         0       3
# ..    ...       ...     ...
# 886   887         0       2
# 887   888         1       1
# 888   889         0       3
# 889   890         1       1
# 890   891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ...

# %%
df.drop(columns = {'Embarked'},inplace = True)

# %%
df
# Out:
#      S.no  Survived  Pclass  \
# 0       1         0       3
# 1       2         1       1
# 2       3         1       3
# 3       4         1       1
# 4       5         0       3
# ..    ...       ...     ...
# 886   887         0       2
# 887   888         1       1
# 888   889         0       3
# 889   890         1       1
# 890   891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ...

# %%
df.shape
# Out:
# (891, 11)

# %% [markdown]
# ### Choosing the number of Unique Values
